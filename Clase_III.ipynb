# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("titanic.csv")

# %%
df
df[["Age","Sex","Survived"]]
# Out:
#       Age     Sex  Survived
# 0    22.0    male         0
# 1    38.0  female         1
# 2    26.0  female         1
# 3    35.0  female         1
# 4    35.0    male         0
# 5     NaN    male         0
# 6    54.0    male         0
# 7     2.0    male         0
# 8    27.0  female         1
# 9    14.0  female         1
# 10    4.0  female         1
# 11   58.0  female         1
# 12   20.0    male         0
# 13   39.0    male         0
# 14   14.0  female         0
# 15   55.0  female         1
# 16    2.0    male         0
# 17    NaN    male         1
# 18   31.0  female         0
# 19    NaN  female         1
# 20   35.0    male         0
# 21   34.0    male         1
# 22   15.0  female         1
# 23   28.0    male         1
# 24    8.0  female         0
# 25   38.0  female         1
# 26    NaN    male         0
# 27   19.0    male         0
# 28    NaN  female         1
# 29    NaN    male         0
# ..    ...     ...       ...
# 861  21.0    male         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.loc[0:10,"Age"]
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# Name: Age, dtype: float64

# %%
df.iloc[0,3]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df[(df["Age"] < 20) & (df["Sex"] == "male")]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 27            28         0       1
# 50            51         0       3
# 59            60         0       3
# 63            64         0       3
# 67            68         0       3
# 78            79         1       2
# 86            87         0       3
# 125          126         1       3
# 138          139         0       3
# 143          144         0       3
# 144          145         0       2
# 145          146         0       2
# 163          164         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 175          176         0       3
# 182          183         0       3
# 183          184         1       2
# 191          192         0       2
# 193          194         1       2
# 204          205         1       3
# 220          221         1       3
# ...

# %%
df[(df["Age"] > 10) & (df["Survived"] == "0")]
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df["Sex2"]=df["Sex"].map({"female":1,"male":0})
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
pd.get_dummies(df["Sex"])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# 5         0     1
# 6         0     1
# 7         0     1
# 8         1     0
# 9         1     0
# 10        1     0
# 11        1     0
# 12        0     1
# 13        0     1
# 14        1     0
# 15        1     0
# 16        0     1
# 17        0     1
# 18        1     0
# 19        1     0
# 20        0     1
# 21        0     1
# 22        1     0
# 23        0     1
# 24        1     0
# 25        1     0
# 26        0     1
# 27        0     1
# 28        1     0
# 29        0     1
# ..      ...   ...
# 861       0     1
# 862       1     0
# 863       1     0
# 864       0     1
# 865       1     0
# 866       1     0
# 867       0     1
# 868       0     1
# 869       0     1
# 870       0     1
# 871       1     0
# 872       0     1
# 873       0     1
# 874       1     0
# 875       1     0
# 876       0     1
# 877       0     1
# 878       0     1
# ...

# %%
pd.get_dummies(df["Embarked"])
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# 5    0  1  0
# 6    0  0  1
# 7    0  0  1
# 8    0  0  1
# 9    1  0  0
# 10   0  0  1
# 11   0  0  1
# 12   0  0  1
# 13   0  0  1
# 14   0  0  1
# 15   0  0  1
# 16   0  1  0
# 17   0  0  1
# 18   0  0  1
# 19   1  0  0
# 20   0  0  1
# 21   0  0  1
# 22   0  1  0
# 23   0  0  1
# 24   0  0  1
# 25   0  0  1
# 26   1  0  0
# 27   0  0  1
# 28   0  1  0
# 29   0  0  1
# ..  .. .. ..
# 861  0  0  1
# 862  0  0  1
# 863  0  0  1
# 864  0  0  1
# 865  0  0  1
# 866  1  0  0
# 867  0  0  1
# 868  0  0  1
# 869  0  0  1
# 870  0  0  1
# 871  0  0  1
# 872  0  0  1
# 873  0  0  1
# 874  1  0  0
# 875  1  0  0
# 876  0  0  1
# 877  0  0  1
# 878  0  0  1
# 879  1  0  0
# 880  0  0  1
# 881  0  0  1
# 882  0  0  1
# 883  0  0  1
# 884  0  0  1
# 885  0  1  0
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
df["Age"].dropna()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 18     31.0
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 27     19.0
# 30     40.0
# 33     66.0
# 34     28.0
# 35     42.0
# 37     21.0
# 38     18.0
#        ...
# 856    45.0
# 857    51.0
# 858    24.0
# 860    41.0
# 861    21.0
# 862    48.0
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
df["Age"].median()
# Out:
# 28.0

# %%
df_miss =df [df["Name"].str.contains("Miss")]

# %%
df_miss.median()
# Out:
# PassengerId    381.50000
# Survived         1.00000
# Pclass           3.00000
# Age             21.00000
# SibSp            0.00000
# Parch            0.00000
# Fare            15.62085
# dtype: float64

# %%
df_miss
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 2              3         1       3                    Heikkinen, Miss. Laina
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 11            12         1       1                  Bonnell, Miss. Elizabeth
# 14            15         0       3      Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# 32            33         1       3                  Glynn, Miss. Mary Agatha
# 38            39         0       3        Vander Planke, Miss. Augusta Maria
# 39            40         1       3               Nicola-Yarred, Miss. Jamila
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ...

# %%
sns.distplot(df_miss["Age"].dropna(), kde=False)

# %%
df["Fare"].median()
# Out:
# 14.4542

# %%
df_mr =df [df["Name"].str.contains("Mr")]

# %%
df_mr
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 15            16         1       2
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 23            24         1       1
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 29            30         0       3
# 31            32         1       1
# 33            34         0       2
# 34            35         0       1
# 35            36         0       1
# ...

# %%
df_miss[df_miss["Age"]<10].describe()
# Out:
#        PassengerId   Survived     Pclass        Age      SibSp      Parch  \
# count    30.000000  30.000000  30.000000  30.000000  30.000000  30.000000
# mean    421.900000   0.633333   2.666667   4.416667   1.533333   1.433333
# std     261.678844   0.490133   0.546672   2.709604   1.407696   0.568321
# min      11.000000   0.000000   1.000000   0.750000   0.000000   0.000000
# 25%     190.250000   0.000000   2.000000   2.000000   0.000000   1.000000
# 50%     459.500000   1.000000   3.000000   4.000000   1.000000   1.000000
# 75%     641.000000   1.000000   3.000000   6.000000   2.750000   2.000000
# max     853.000000   1.000000   3.000000   9.000000   4.000000   2.000000
#
#              Fare
# count   30.000000
# mean    27.972637
# std     24.780829
# min     10.462500
# 25%     17.339575
# 50%     24.500000
# 75%     31.275000
# max    151.550000

# %%
df_miss[df_miss["Age"]>10].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   115.000000  115.000000  115.000000  115.000000  115.000000
# mean    409.208696    0.747826    2.026087   26.404348    0.373913
# std     247.111080    0.436161    0.893062   10.518550    0.893062
# min       3.000000    0.000000    1.000000   11.000000    0.000000
# 25%     214.000000    0.500000    1.000000   18.000000    0.000000
# 50%     388.000000    1.000000    2.000000   24.000000    0.000000
# 75%     598.000000    1.000000    3.000000   31.000000    0.000000
# max     888.000000    1.000000    3.000000   63.000000    5.000000
#
#             Parch       Fare
# count  115.000000  115.00000
# mean     0.356522   55.40953
# std      0.715631   78.87342
# min      0.000000    6.75000
# 25%      0.000000    8.34585
# 50%      0.000000   13.85830
# 75%      0.000000   78.55835
# max      2.000000  512.32920

# %%
df["Sex"] = df["Sex"].map({"male":0,"female":1})

# %%
df.groupby("Sex").mean().Survived
# Out:
# Sex
# 0    0.188908
# 1    0.742038
# Name: Survived, dtype: float64

# %%
df= df.dropna()

# %%
x= df[["Age","Pclass","Sex"]]

# %%
y= df["Survived"]

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr =LogisticRegression()

# %%
lr.fit(x,y)#Entrenarlo
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr.predict_proba([[15,1,0]])# %morir  %vivir
# Out:
# array([[0.38792764, 0.61207236]])

# %%
lr.predict([[20,1,0]])
# Out:
# array([1])

# %%
lr.predict([[9,1,0]])
# Out:
# array([1])

# %%
lr.predict([[15,3,0]])
# Out:
# array([0])

# %%
lr.score(x,y) #da el rendimiento
# Out:
# 0.7650273224043715

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train , y_test =train_test_split(x,y,test_size=  0.7) # test size divide la muestra para entrenar y otra para provar 
lr =LogisticRegression()
lr.fit(x_train,y_train)
lr.score(x_test,y_test) #da el rendimiento
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.7906976744186046

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
df= DecisionTreeClassifier() 
lr.fit(x_train,y_train)
lr.score(x_test,y_test) #da el rendimiento
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.7906976744186046
