# %% [markdown]
# Creaciòn de listas por extensiòn

# %%
x=[1,2,3,4,5,6]

# %% [markdown]
# Creaciòn de una lista por comprensiòn

# %%
y=[a ** 2 for a in x]
y
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
 [a * 3 for a in list(range(1, 10))]
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27]

# %%
[a * 3 for a in list(range(1, 10)) if a%5==0]
# Out:
# [15]

# %%
a=[]

# %% [markdown]
# # GENERADORES

# %%
def pares(x,y):
    a=[]
    if x%2==1:
        x=x+1
    for i in range(x,y+1,2):
        a.append(i)
    return a

# %%
pares(2,8)
# Out:
# [2, 4, 6, 8]

# %%
pares(7,14)
# Out:
# [8, 10, 12, 14]

# %%
def par(x,y):
    return [i for i in list(range(x,y+1))if i%2==0]

# %%
par(2,8)
# Out:
# [2, 4, 6, 8]

# %%
pares(7,14)
# Out:
# [8, 10, 12, 14]

# %%
def gen_pares(x,y):
    if x%2==1:
        x=x+1
    for i in range(x,y+1,2):
        yield i

# %%
b=gen_pares(2,8)

# %%
for w in b:
    print(w)
# Out:
# 2
# 4
# 6
# 8

# %%
def fibonacci(n):
    a,b= 0,1
    for i in range(n+1):
        print(a, end=' ')
        a,b= b, a+b
    print()

# %%
fibonacci(11)

# %% [markdown]
# Fibonacci con Generador

# %%
def fibonacci(n):
    a,b= 0,1
    for i in range(n):
        yield a
        a,b= b, a+b

# %%
fib=int(input('Introduzca un número entero no negativo:'))

# %%
for z in fibonacci(fib):
    print(z)

# %%
h = n*n+2
cousin = []
for x in range(2, h):
	    I_think_cousin = True
	    for divisor in range(2, x):
		    if x % divisor == 0:
			    I_think_cousin = False
			    break
	    if I_think_cousin and len(cousin)<n:
		    cousin.append(x)
print(cousin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4452dfcf4beb> in <module>()
#       1
# ----> 2 h = n*n+2
#       3 cousin = []
#       4 for x in range(2, h):
#       5             I_think_cousin = True
#
# NameError: name 'n' is not defined
